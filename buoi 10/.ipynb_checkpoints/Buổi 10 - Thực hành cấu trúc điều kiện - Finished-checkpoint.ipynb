# %% [markdown]
# # Thực hành cấu trúc điều khiển
#
# ### Bài 1
#
# Cho phương trình bậc 2: ax^2 + bx + c = 0
#
# Nhập a, b, c
#
# Giải và biện luận phương trình trên

# %%
## Nhập a, b, c
## nếu a = 0 thì như nào?
#### nếu b = 0 thì như nào
#### nếu b != 0 thì ...

## nếu a != 0 thì như nào??

a = float(input("Nhập vào a: "))
b = float(input("Nhập vào b: "))
c = float(input("Nhập vào c: "))

if a == 0:
    ### phương trình của mình ~~> bx + c = 0
    if b == 0:
        ### phương trình của mình ~~> c = 0
        if c == 0:
            ### phương trình cảu mình ~~> 0 = 0 ~~> phương trình luôn đúng
            print("Phương trình vô số nghiệm")
        else: ## khi c khác 0
            print("Phương trình vô nghiệm")
    else: ## khi b khác 0
        x = -c/b
        print("Phương trình có 1 nghiệm:",x)
else: ### a khác 0
    delta = b**2 - 4*a*c
    if delta > 0:
        can_delta = delta**0.5
        x1 = (-b + can_delta)/(2*a)
        x2 = (-b - can_delta)/(2*a)
        print("Phương trình có 2 nghiệm phân biệt:",x1,x2)
    elif delta == 0:
        x = (-b)/(2*a)
        print("Phương trình có một nghiệm kép:",x)
    else:
        print("Phương trình vô nghiệm")
# Out:
# Nhập vào a: 1
# Nhập vào b: 7
# Nhập vào c: 12
# Phương trình có 2 nghiệm phân biệt: -3.0 -4.0

# %% [markdown]
# ### Bài 2
#
# Hãy nhập vào một số
#
# Xác định coi đó có phải là số nguyên tố hay không

# %%
### số nguyên tố là số chỉ có 2 ước 1 và chính nó
##### ví dụ: số 7 là số nguyên tố vì nó chỉ có 2 ước: 7 và 1
##### a là ước của b nếu b chia hết cho a

a = int(input("Nhập vào a:"))
uoc = 1
dem = 0
for i in range(a):
    if a%uoc == 0: ### chỉ in ra những số mà a chia hết
        dem += 1
    uoc += 1
    
if dem == 2:
    print("Đây là số nguyên tố")
else:
    print("Đây không là số nguyên tố")
# Out:
# Nhập vào a:1
# Đây không là số nguyên tố

# %% [markdown]
# ### Bài 3
#
# Hãy nhập vào số n
#
# Hãy đếm số chữ số 0 tận cùng của n giai thừa
#
# (Bài này nâng cao, mọi người có thể bỏ qua)

# %% [markdown]
# ### Bài 4
#
# In ra tất cả các số chia hết cho 3 nhỏ hơn 100

# %%
a = 1
for i in range(100):
    if a % 3 == 0:
        print(a)
    a += 1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# ### Bài 5
#
# In ra tất cả các số lẻ nhưng không chia hết cho 3 nhỏ hơn 100

# %%
a = 1
for i in range(100):
    if a % 3 != 0 and a % 2 != 0:
        print(a)
    a += 1
# Out:
# 1
# 5
# 7
# 11
# 13
# 17
# 19
# 23
# 25
# 29
# 31
# 35
# 37
# 41
# 43
# 47
# 49
# 53
# 55
# 59
# 61
# 65
# 67
# 71
# 73
# 77
# 79
# 83
# 85
# 89
# 91
# 95
# 97

# %% [markdown]
# ### Bài 5
#
# Tại một cửa hàng nọ có menu như sau:
#
# 1. Gà rán giá 35k
# 2. Hamburger giá 50k
# 3. Pesi giá 10k
#
# Nhập số lượng món hàng cần mua
#
# Tính và in ra tổng giá tiền (hiển thị có dấu chấm mỗi 3 chữ số để người dùng để quan sát)
#
# Nếu giá trị đơn hàng trên 2 triệu, giảm 10% cho khách, trên 4 triệu, giảm 15%
#
# Tính và in ra tổng giá tiền được giảm (hiển thị có dấu chấm mỗi 3 chữ số để người dùng để quan sát)
#
# Tính và in ra tổng giá tiền khách cần trả (hiển thị có dấu chấm mỗi 3 chữ số để người dùng để quan sát)
#
# In ra dòng chữ "Cảm ơn quý khách đã mua hàng"

# %%
print("Chào mừng các bạn đến với cửa hàng của chúng tôi")
print()
print("Menu")
print("----------------------------------")
print("Gà rán: 35.000đ")
print("Hamburger: 50.000đ")
print("Pesi: 10.000đ")
print("----------------------------------")
print()
print("----------------------------------")
garan = int(input("Nhập số lượng gà rán cần mua:"))
ham = int(input("Nhập số lượng hamburger cần mua:"))
pesi = int(input("Nhập số lượng pesi cần mua:"))
print("----------------------------------")
print()
tong = garan*35000 + ham*50000 + pesi*10000
print("Tổng:",f"{tong:,}".replace(",",".")+"đ")
giamgia = 0
if tong > 4000000:
    print("Bạn được giảm 15%")
    giamgia = int(tong*0.15)
elif tong > 2000000:
    print("Bạn được giảm 10%")
    giamgia = int(tong*0.1)
print("Tổng tiền được giảm:",f"{giamgia:,}".replace(",",".")+"đ")
print("Tổng tiền cần thanh toán:",f"{tong-giamgia:,}".replace(",",".")+"đ")
print()
print("Cảm ơn quý khách đã mua hàng")
# Out:
# Chào mừng các bạn đến với cửa hàng của chúng tôi
#
# Menu
# ----------------------------------
# Gà rán: 35.000đ
# Hamburger: 50.000đ
# Pesi: 10.000đ
# ----------------------------------
#
# ----------------------------------
# Nhập số lượng gà rán cần mua:50
# Nhập số lượng hamburger cần mua:50
# Nhập số lượng pesi cần mua:50
# ----------------------------------
#
# Tổng: 4.750.000đ
# Bạn được giảm 15%
# Tổng tiền được giảm: 712.500đ
# Tổng tiền cần thanh toán: 4.037.500đ
#
# Cảm ơn quý khách đã mua hàng

# %% [markdown]
# ### Bài 6
#
# Nhập vào chiều cao (cm) và cân nặng (kg), tính số BMI và xét rồi xin kết quả theo dữ liệu sau:
#
# - BMI < 16: Gầy cấp độ III
# - 16 <= BMI < 17:  Gầy cấp độ II
# - 17<= BMI < 18.5: Gầy cấp độ I
# - 18.5 <= BMI < 25: Bình thường
# - 25 <= BMI < 30: Thừa cân
# - 30 <= BMI < 35 : Béo phì cấp độ I
# - 35 <= BMI < 40: Béo phì cấp độ II
# - BMI > 40: Béo phì cấp độ III

# %%
chieu_cao = float(input("Nhập chiều cao (cm):"))
can_nang = float(input("Nhập cân nặng (kg):"))
BMI = can_nang/((chieu_cao/100)**2)
print(BMI)
if BMI < 16:
    print("Gầy cấp độ III")
elif BMI < 17:
    print("Gầy cấp độ II")
elif BMI < 18.5:
    print("Gầy cấp độ I")
elif BMI < 25:
    print("Bình thường")
elif BMI < 30:
    print("Thừa cân")
elif BMI < 35:
    print("Béo phì cấp độ I")
elif BMI < 40:
    print("Béo phì cấp độ II")
else:
    print("Béo phì cấp độ III")
# Out:
# Nhập chiều cao (cm):166
# Nhập cân nặng (kg):80
# 29.03178980984178
# Thừa cân

# %% [markdown]
# ### Bài 7
#
# Nhập ngày, tháng, năm. Hãy tính và in ra màn hình kể từ đầu năm đến ngày vừa nhập là bao nhiêu ngày.

# %%
ngay = int(input("Nhập vào ngày:"))
thang = int(input("Nhập vào tháng:"))
nam = int(input("Nhập vào năm:"))

### nếu giả sử mình nhập 14 tháng 5 ~~> mình sẽ tính là tháng 1 + tháng 2 + tháng 3 + tháng 4 + 14 ngày
i_thang = 1
songay = ngay
for i in range(thang-1):
    ### những tháng có 31 ngày là: 1, 3, 5, 7, 8, 10, 12
    if i_thang == 1 or i_thang == 3 or i_thang == 5 or i_thang == 7 or i_thang == 8 or i_thang == 10 or i_thang == 12:
        ngay += 31
    ### những tháng có 30 ngày là: 4, 6, 9, 11
    elif i_thang == 4 or i_thang == 6 or i_thang == 9 or i_thang == 11:
        ngay += 30
    ### trường hợp tháng 2
    else:
        if nam % 4 == 0:
            ngay += 29
        else:
            ngay += 28
    i_thang += 1

print(ngay)
# Out:
# Nhập vào ngày:14
# Nhập vào tháng:5
# Nhập vào năm:1990
# 134
